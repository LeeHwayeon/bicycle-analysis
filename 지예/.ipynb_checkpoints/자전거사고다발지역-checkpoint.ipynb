# %%
import pandas as pd

# %%
acc = pd.read_csv('data/사고다발지역.csv', encoding='euc-kr')
acc
# Out:
#        사고다발지FID  사고다발지ID       법정동코드      지점코드      시도시군구명  \
# 0       161,307  2013099  1111013400  11110001  서울특별시 종로구1
# 1       153,927  2013099  1111012300  11110002  서울특별시 종로구2
# 2       153,929  2013099  1111017500  11110003  서울특별시 종로구3
# 3       139,637  2013099  1114016300  11140001   서울특별시 중구1
# 4       153,931  2013099  1117012800  11170001  서울특별시 용산구1
# ...         ...      ...         ...       ...         ...
# 2713  6,519,999  2019038  4825010300  48250001   경상남도 김해시1
# 2714  6,515,611  2019038  4825010800  48250002   경상남도 김해시2
# 2715  6,516,316  2019038  4825010200  48250003   경상남도 김해시3
# 2716  6,520,305  2019038  4833025324  48330001   경상남도 양산시1
# 2717  6,516,388  2019038  4874025321  48740001   경상남도 창녕군1
#
#                                        지점명  발생건수  사상자수  사망자수  중상자수  경상자수  \
# 0                    서울특별시 종로구 경운동(안국역 부근)     4     4     0     0     3
# 1                   서울특별시 종로구 서린동(SK빌딩 부근)     4     4     0     1     2
# ...

# %%
data = acc[acc['발생건수'] >= 10]
data
# Out:
#        사고다발지FID  사고다발지ID       법정동코드      지점코드          시도시군구명  \
# 24      154,565  2013099  1121510700  11215016     서울특별시 광진구16
# 51      163,202  2013099  1126010300  11260012     서울특별시 중랑구12
# 64      161,626  2013099  1132010800  11320006      서울특별시 도봉구6
# 175     157,441  2013099  1171010600  11710025     서울특별시 송파구25
# 186     161,952  2013099  1174010800  11740011     서울특별시 강동구11
# 209     162,249  2013099  2711010100  27110006       대구광역시 중구6
# 228     159,685  2013099  2717010100  27170011      대구광역시 서구11
# 229     158,406  2013099  2717010200  27170012      대구광역시 서구12
# 383     160,987  2013099  4311310100  43113011  충청북도 청주시 흥덕구11
# 473     200,003  2014109  1123010300  11230001     서울특별시 동대문구1
# 474   5,468,976  2014109  1123010200  11230002     서울특별시 동대문구2
# 647     202,891  2014109  2711011200  27110001       대구광역시 중구1
# 661     203,204  2014109  2717010300  27170001       대구광역시 서구1
# 804     204,829  2014109  4119510800  41195001    경기도 부천시 원미구1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59 entries, 24 to 2690
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   사고다발지FID  59 non-null     object
#  1   사고다발지ID   59 non-null     int64
#  2   법정동코드     59 non-null     int64
#  3   지점코드      59 non-null     int64
#  4   시도시군구명    59 non-null     object
#  5   지점명       59 non-null     object
#  6   발생건수      59 non-null     int64
#  7   사상자수      59 non-null     int64
#  8   사망자수      59 non-null     int64
#  9   중상자수      59 non-null     int64
#  10  경상자수      59 non-null     int64
#  11  부상신고자수    59 non-null     int64
#  12  경도        59 non-null     float64
#  13  위도        59 non-null     float64
#  14  다발지역폴리곤   59 non-null     object
# dtypes: float64(2), int64(9), object(4)
# memory usage: 7.4+ KB
