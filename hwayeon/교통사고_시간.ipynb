# %%
import pandas as pd
# %matplotlib inline 
 
## matplotlib의 pyplot import
import matplotlib
import matplotlib.pyplot as plt

import matplotlib.font_manager as fm

# %%
accident2017=pd.read_csv('data/2017교통사고_시간.csv',encoding='euc-kr')
accident2018=pd.read_csv('data/2018교통사고_시간.csv',encoding='euc-kr')

# %%
accident2017
# Out:
#          시간  사고건수  사망자수  부상자수  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0     0시~2시    31     0    32         NaN         NaN         NaN         NaN
# 1     2시~4시    17     0    19         NaN         NaN         NaN         NaN
# 2     4시~6시    31     2    29         NaN         NaN         NaN         NaN
# 3     6시~8시   102     1   110         NaN         NaN         NaN         NaN
# 4    8시~10시   206     4   214         NaN         NaN         NaN         NaN
# 5   10시~12시   153     3   157         NaN         NaN         NaN         NaN
# 6   12시~14시   168     1   177         NaN         NaN         NaN         NaN
# 7   14시~16시   236     3   262         NaN         NaN         NaN         NaN
# 8   16시~18시   237     0   261         NaN         NaN         NaN         NaN
# 9   18시~20시   220     1   237         NaN         NaN         NaN         NaN
# 10  20시~22시   151     1   159         NaN         NaN         NaN         NaN
# ...

# %%
accident2018
# Out:
#          시간  사고건수  사망자수  부상자수  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0     0시~2시    32     0    35         NaN         NaN         NaN         NaN
# 1     2시~4시    13     1    12         NaN         NaN         NaN         NaN
# 2     4시~6시    34     3    35         NaN         NaN         NaN         NaN
# 3     6시~8시    86     0    91         NaN         NaN         NaN         NaN
# 4    8시~10시   157     1   171         NaN         NaN         NaN         NaN
# 5   10시~12시   148     2   154         NaN         NaN         NaN         NaN
# 6   12시~14시   140     2   144         NaN         NaN         NaN         NaN
# 7   14시~16시   202     1   214         NaN         NaN         NaN         NaN
# 8   16시~18시   245     3   268         NaN         NaN         NaN         NaN
# 9   18시~20시   190     0   203         NaN         NaN         NaN         NaN
# 10  20시~22시   137     3   151         NaN         NaN         NaN         NaN
# ...

# %%
accident2017=accident2017.dropna(how='all',axis=1)
accident2018=accident2018.dropna(how='all',axis=1)

# %%
accident2017
# Out:
#          시간  사고건수  사망자수  부상자수
# 0     0시~2시    31     0    32
# 1     2시~4시    17     0    19
# 2     4시~6시    31     2    29
# 3     6시~8시   102     1   110
# 4    8시~10시   206     4   214
# 5   10시~12시   153     3   157
# 6   12시~14시   168     1   177
# 7   14시~16시   236     3   262
# 8   16시~18시   237     0   261
# 9   18시~20시   220     1   237
# 10  20시~22시   151     1   159
# 11  22시~24시   107     0   119

# %%
accident2018
# Out:
#          시간  사고건수  사망자수  부상자수
# 0     0시~2시    32     0    35
# 1     2시~4시    13     1    12
# 2     4시~6시    34     3    35
# 3     6시~8시    86     0    91
# 4    8시~10시   157     1   171
# 5   10시~12시   148     2   154
# 6   12시~14시   140     2   144
# 7   14시~16시   202     1   214
# 8   16시~18시   245     3   268
# 9   18시~20시   190     0   203
# 10  20시~22시   137     3   151
# 11  22시~24시    87     2    95

# %%
accident2017.info()
accident2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시간      12 non-null     object
#  1   사고건수    12 non-null     int64
#  2   사망자수    12 non-null     int64
#  3   부상자수    12 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 512.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시간      12 non-null     object
#  1   사고건수    12 non-null     int64
#  2   사망자수    12 non-null     int64
#  3   부상자수    12 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 512.0+ bytes

# %%
accident2017.plot(kind='bar', figsize=(12,5),rot=0,title="시간별 교통사고")
accident2017.index=accident2017['시간']
plt.rc('font', family='NanumGothic')
plt.box(False)
plt.tight_layout()
plt.show()
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
accident2018.plot(kind='bar', figsize=(12,5),rot=0,title="시간별 교통사고")
accident2018.index=accident2018['시간']
plt.rc('font', family='NanumGothic')
plt.box(False)
plt.tight_layout()
plt.show()
