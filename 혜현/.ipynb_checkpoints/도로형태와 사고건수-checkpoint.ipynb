# %%
import json
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium import plugins
import missingno as mnso

import warnings
warnings.filterwarnings('ignore')

geo_path = 'data/seoul_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["font.family"] = 'Malgun Gothic'

# %%
accidList = pd.read_csv('data/accidentInfoList.csv')
accidList.head()
# Out:
#                사고번호             사고일시   요일             시군구  사고내용  사망자수  중상자수  \
# 0  2017010200100055  2017년 1월 2일 05시  월요일   서울특별시 광진구 화양동  경상사고     0     0
# 1  2017010200100060  2017년 1월 2일 06시  월요일   서울특별시 강북구 미아동  중상사고     0     1
# 2  2017010300100168  2017년 1월 3일 09시  화요일   서울특별시 마포구 합정동  경상사고     0     0
# 3  2017010300100197  2017년 1월 3일 10시  화요일  서울특별시 영등포구 신길동  경상사고     0     0
# 4  2017010300100201  2017년 1월 3일 10시  화요일   서울특별시 양천구 신정동  경상사고     0     0
#
#    경상자수  부상신고자수        사고유형  ... 기상상태        도로형태 가해운전자 차종 가해운전자 성별 가해운전자 연령  \
# 0     1       0   차대사람 - 기타  ...    비     기타 - 기타      자전거        남      27세
# 1     0       0    차대차 - 추돌  ...   흐림  교차로 - 교차로안      자전거        남      73세
# 2     1       0  차대차 - 측면충돌  ...   흐림  교차로 - 교차로안      자전거        여      45세
# 3     1       0    차대차 - 기타  ...   맑음    단일로 - 기타      자전거        남      67세
# 4     1       0  차대차 - 측면충돌  ...   맑음  교차로 - 교차로안      자전거        남      13세
#
#   가해운전자 상해정도 피해운전자 차종 피해운전자 성별 피해운전자 연령 피해운전자 상해정도
# 0       상해없음      보행자        여      74세         경상
# 1         중상       승용        남      39세       상해없음
# 2         경상       승용        남      74세       상해없음
# 3         경상       승합        남      35세       상해없음
# 4         경상       승합        남      41세       상해없음
#
# [5 rows x 22 columns]

# %%
accidList.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3127 entries, 0 to 3126
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   사고번호        3127 non-null   int64
#  1   사고일시        3127 non-null   object
#  2   요일          3127 non-null   object
#  3   시군구         3127 non-null   object
#  4   사고내용        3127 non-null   object
#  5   사망자수        3127 non-null   int64
#  6   중상자수        3127 non-null   int64
#  7   경상자수        3127 non-null   int64
#  8   부상신고자수      3127 non-null   int64
#  9   사고유형        3127 non-null   object
#  10  법규위반        3127 non-null   object
#  11  노면상태        3127 non-null   object
#  12  기상상태        3127 non-null   object
#  13  도로형태        3127 non-null   object
#  14  가해운전자 차종    3127 non-null   object
#  15  가해운전자 성별    3127 non-null   object
#  16  가해운전자 연령    3127 non-null   object
#  17  가해운전자 상해정도  3127 non-null   object
#  18  피해운전자 차종    3070 non-null   object
#  19  피해운전자 성별    3070 non-null   object
#  20  피해운전자 연령    3070 non-null   object
#  21  피해운전자 상해정도  3070 non-null   object
# dtypes: int64(5), object(17)
# memory usage: 537.6+ KB

# %%
road = accidList.groupby('도로형태').size()
road
# Out:
# 도로형태
# 교차로 - 교차로부근         363
# 교차로 - 교차로안          673
# 교차로 - 교차로횡단보도내      201
# 기타 - 기타             334
# 단일로 - 고가도로위           1
# 단일로 - 교량             14
# 단일로 - 기타           1513
# 단일로 - 지하차도(도로)내      15
# 단일로 - 터널              2
# 미분류 - 미분류             6
# 주차장 - 주차장             5
# dtype: int64

# %%
ax = road.plot(kind='bar', figsize=(18, 5), rot=0, title="도로형태별 사고건수")
for p in ax.patches: 
    left, bottom, width, height = p.get_bbox().bounds 
    ax.annotate("%d"%(height), (left+width/2, height+2), ha='center')
plt.box(False)
plt.xlabel('')
plt.tight_layout()
plt.show()

# %%
accidList['지역구']=accidList['시군구'].str.split(" ").str[1]
accidList
# Out:
#                   사고번호               사고일시   요일             시군구  사고내용  사망자수  \
# 0     2017010200100055    2017년 1월 2일 05시  월요일   서울특별시 광진구 화양동  경상사고     0
# 1     2017010200100060    2017년 1월 2일 06시  월요일   서울특별시 강북구 미아동  중상사고     0
# 2     2017010300100168    2017년 1월 3일 09시  화요일   서울특별시 마포구 합정동  경상사고     0
# 3     2017010300100197    2017년 1월 3일 10시  화요일  서울특별시 영등포구 신길동  경상사고     0
# 4     2017010300100201    2017년 1월 3일 10시  화요일   서울특별시 양천구 신정동  경상사고     0
# ...                ...                ...  ...             ...   ...   ...
# 3122  2018122900100411  2018년 12월 29일 20시  토요일   서울특별시 송파구 삼전동  경상사고     0
# 3123  2018123100100041  2018년 12월 31일 05시  월요일   서울특별시 송파구 삼전동  중상사고     0
# 3124  2018123100100193  2018년 12월 31일 12시  월요일   서울특별시 노원구 하계동  중상사고     0
# 3125  2018123100100347  2018년 12월 31일 16시  월요일   서울특별시 양천구 신월동  경상사고     0
# 3126  2018123100100382  2018년 12월 31일 17시  월요일    서울특별시 양천구 목동  경상사고     0
#
#       중상자수  경상자수  부상신고자수        사고유형  ...         도로형태 가해운전자 차종 가해운전자 성별  \
# 0        0     1       0   차대사람 - 기타  ...      기타 - 기타      자전거        남
# 1        1     0       0    차대차 - 추돌  ...   교차로 - 교차로안      자전거        남
# 2        0     1       0  차대차 - 측면충돌  ...   교차로 - 교차로안      자전거        여
# 3        0     1       0    차대차 - 기타  ...     단일로 - 기타      자전거        남
# 4        0     1       0  차대차 - 측면충돌  ...   교차로 - 교차로안      자전거        남
# ...    ...   ...     ...         ...  ...          ...      ...      ...
# 3122     0     1       0   차대사람 - 기타  ...      기타 - 기타      자전거        남
# 3123     1     0       0    차대차 - 기타  ...  교차로 - 교차로부근      자전거        남
# 3124     1     0       0  차대차 - 측면충돌  ...     단일로 - 기타      자전거        남
# 3125     0     1       0    차대차 - 기타  ...   교차로 - 교차로안      자전거        남
# 3126     0     1       0  차대차 - 측면충돌  ...      기타 - 기타      자전거        남
#
#      가해운전자 연령 가해운전자 상해정도 피해운전자 차종 피해운전자 성별 피해운전자 연령 피해운전자 상해정도   지역구
# 0         27세       상해없음      보행자        여      74세         경상   광진구
# 1         73세         중상       승용        남      39세       상해없음   강북구
# 2         45세         경상       승용        남      74세       상해없음   마포구
# 3         67세         경상       승합        남      35세       상해없음  영등포구
# 4         13세         경상       승합        남      41세       상해없음   양천구
# ...       ...        ...      ...      ...      ...        ...   ...
# 3122      14세       상해없음      보행자        남      37세         경상   송파구
# 3123      79세         중상       승용        남      77세       상해없음   송파구
# 3124      67세         중상       승용        남      41세       상해없음   노원구
# 3125      74세         경상       승용        남      61세       상해없음   양천구
# 3126      68세         경상       승용        남      48세       상해없음   양천구
#
# [3127 rows x 23 columns]

# %%
accidList_gu = {}
for idx, df in accidList.groupby('지역구'):
    accidList_road = []
    for i, i_row in df.iterrows():
        accidList_road.append(i_row['도로형태'])
    accidList_gu[idx] = accidList_road
accidList_gu
# Out:
# {'강남구': ['단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '주차장 - 주차장',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로부근'],
#  '강동구': ['단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 교량',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 교량',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 지하차도(도로)내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안'],
#  '강북구': ['교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타'],
#  '강서구': ['교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '미분류 - 미분류',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근'],
#  '관악구': ['단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근'],
#  '광진구': ['기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 교량',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 교량',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 교량',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타'],
#  '구로구': ['단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '단일로 - 고가도로위',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안'],
#  '금천구': ['교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '교차로 - 교차로안'],
#  '노원구': ['단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 지하차도(도로)내',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로횡단보도내',
#   '주차장 - 주차장',
#   '단일로 - 지하차도(도로)내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '주차장 - 주차장',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 지하차도(도로)내',
#   '기타 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 지하차도(도로)내',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 지하차도(도로)내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 지하차도(도로)내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 교량',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 지하차도(도로)내',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타'],
#  '도봉구': ['교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타'],
#  '동대문구': ['교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '주차장 - 주차장',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안'],
#  '동작구': ['교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 지하차도(도로)내',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근'],
#  '마포구': ['교차로 - 교차로안',
#   '단일로 - 기타',
#   '미분류 - 미분류',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 교량',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타'],
#  '서대문구': ['단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타'],
#  '서초구': ['단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 지하차도(도로)내',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '미분류 - 미분류',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '미분류 - 미분류',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타'],
#  '성동구': ['단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 교량',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근'],
#  '성북구': ['단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타'],
#  '송파구': ['교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '주차장 - 주차장',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 교량',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 교량',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '미분류 - 미분류',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로부근'],
#  '양천구': ['교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 교량',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타'],
#  '영등포구': ['단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 교량',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 지하차도(도로)내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 터널',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 터널',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타'],
#  '용산구': ['교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 지하차도(도로)내',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 교량',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 교량',
#   '단일로 - 기타',
#   '단일로 - 지하차도(도로)내',
#   '교차로 - 교차로안',
#   '기타 - 기타'],
#  '은평구': ['교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타'],
#  '종로구': ['단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 지하차도(도로)내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안'],
#  '중구': ['교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 지하차도(도로)내',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타'],
#  '중랑구': ['교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '교차로 - 교차로부근',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '교차로 - 교차로안',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '미분류 - 미분류',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '단일로 - 기타',
#   '기타 - 기타',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '교차로 - 교차로횡단보도내',
#   '단일로 - 기타',
#   '교차로 - 교차로부근',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안',
#   '교차로 - 교차로안',
#   '단일로 - 기타',
#   '교차로 - 교차로안']}

# %%
accidList_gu_road = accidList.groupby(['지역구', '도로형태']).size()
accidList_gu_road
# Out:
# 지역구  도로형태
# 강남구  교차로 - 교차로부근       14
#      교차로 - 교차로안        13
#      교차로 - 교차로횡단보도내     6
#      기타 - 기타           24
#      단일로 - 기타          64
#                        ..
# 중랑구  교차로 - 교차로안        56
#      교차로 - 교차로횡단보도내    15
#      기타 - 기타           18
#      단일로 - 기타          79
#      미분류 - 미분류          1
# Length: 152, dtype: int64

# %%
type(accidList_gu_road)
# Out:
# pandas.core.series.Series

# %%
type(accidList)
# Out:
# pandas.core.frame.DataFrame

# %%
accidList_gu_road = accidList_gu_road.to_frame()
accidList_gu_road.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-307-4911740218ef> in <module>
# ----> 1 accidList_gu_road = accidList_gu_road.to_frame()
#       2 accidList_gu_road.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'

# %%
accidList_gu_road.columns.values
# Out:
# array([0], dtype=int64)

# %%
accidList_gu_road.columns = ['사고건수']
accidList_gu_road
# Out:
#                     사고건수
# 지역구  도로형태
# 강남구  교차로 - 교차로부근      14
#      교차로 - 교차로안       13
#      교차로 - 교차로횡단보도내    6
#      기타 - 기타          24
#      단일로 - 기타         64
# ...                  ...
# 중랑구  교차로 - 교차로횡단보도내   15
#      기타 - 기타          18
#      단일로 - 기타         79
#      미분류 - 미분류         1
# 도로형태                 NaN
#
# [153 rows x 1 columns]

# %%
accidList_gu_road.columns.values
# Out:
# array(['사고건수'], dtype=object)

# %%
accidList_gu_road.reset_index(level=1, inplace=True)

# %%
accidList_gu_road
# Out:
#                 도로형태 사고건수
# 지역구
# 강남구      교차로 - 교차로부근   14
# 강남구       교차로 - 교차로안   13
# 강남구   교차로 - 교차로횡단보도내    6
# 강남구          기타 - 기타   24
# 강남구         단일로 - 기타   64
# ...              ...  ...
# 중랑구   교차로 - 교차로횡단보도내   15
# 중랑구          기타 - 기타   18
# 중랑구         단일로 - 기타   79
# 중랑구        미분류 - 미분류    1
# 도로형태                  NaN
#
# [153 rows x 2 columns]

# %%
accidList_gu_road.columns.values
# Out:
# array(['도로형태', '사고건수'], dtype=object)

# %%
max_idx = accidList_gu_road.groupby(['지역구'])['사고건수'].transform(max) == accidList_gu_road['사고건수']
accidList_gu_road[max_idx]
# Out:
#           도로형태 사고건수
# 지역구
# 강남구   단일로 - 기타   64
# 강동구   단일로 - 기타   62
# 강북구   단일로 - 기타   41
# 강서구   단일로 - 기타   63
# 관악구   단일로 - 기타   31
# 광진구   단일로 - 기타   64
# 구로구   단일로 - 기타   41
# 금천구   단일로 - 기타   23
# 노원구   단일로 - 기타   66
# 도봉구   단일로 - 기타   44
# 동대문구  단일로 - 기타   98
# 동작구   단일로 - 기타   60
# 마포구   단일로 - 기타   48
# 서대문구  단일로 - 기타   34
# 서초구   단일로 - 기타   34
# 성동구   단일로 - 기타   51
# 성북구   단일로 - 기타   51
# 송파구   단일로 - 기타  196
# 양천구   단일로 - 기타   60
# 영등포구  단일로 - 기타  183
# 용산구   단일로 - 기타   40
# 은평구   단일로 - 기타   36
# 종로구   단일로 - 기타   33
# 중구    단일로 - 기타   11
# 중랑구   단일로 - 기타   79

# %%
min_idx = accidList_gu_road.groupby(['지역구'])['사고건수'].transform(min) == accidList_gu_road['사고건수']
accidList_gu_road[min_idx]
# Out:
#                  도로형태  사고건수
# 지역구
# 강남구         주차장 - 주차장     1
# 강동구   단일로 - 지하차도(도로)내     1
# 강북구           기타 - 기타     5
# 강서구         미분류 - 미분류     1
# 관악구    교차로 - 교차로횡단보도내     2
# 광진구          단일로 - 교량     3
# 구로구       단일로 - 고가도로위     1
# 금천구           기타 - 기타     3
# 노원구          단일로 - 교량     1
# 도봉구           기타 - 기타     5
# 동대문구        주차장 - 주차장     1
# 동작구   단일로 - 지하차도(도로)내     1
# 마포구          단일로 - 교량     1
# 마포구         미분류 - 미분류     1
# 서대문구   교차로 - 교차로횡단보도내     3
# 서초구   단일로 - 지하차도(도로)내     1
# 성동구          단일로 - 교량     1
# 성북구           기타 - 기타     5
# 송파구         미분류 - 미분류     1
# 송파구         주차장 - 주차장     1
# 양천구          단일로 - 교량     1
# 영등포구         단일로 - 교량     1
# 영등포구  단일로 - 지하차도(도로)내     1
# 용산구    교차로 - 교차로횡단보도내     1
# 은평구           기타 - 기타     5
# 종로구   단일로 - 지하차도(도로)내     1
# 중구    단일로 - 지하차도(도로)내     1
# 중랑구         미분류 - 미분류     1

# %%
accidList_gu_road['도로형태'] = accidList_gu_road['도로형태'].str.replace(pat='교차로 - 교차로부근', repl='교차로', regex=False)
accidList_gu_road['도로형태'] = accidList_gu_road['도로형태'].str.replace(pat='교차로 - 교차로안', repl='교차로', regex=False)
accidList_gu_road['도로형태'] = accidList_gu_road['도로형태'].str.replace(pat='교차로 - 교차로횡단보도내', repl='교차로', regex=False)

# %%
accidList_gu_road
# Out:
#            도로형태 사고건수
# 지역구
# 강남구         교차로   14
# 강남구         교차로   13
# 강남구         교차로    6
# 강남구     기타 - 기타   24
# 강남구    단일로 - 기타   64
# ...         ...  ...
# 중랑구         교차로   15
# 중랑구     기타 - 기타   18
# 중랑구    단일로 - 기타   79
# 중랑구   미분류 - 미분류    1
# 도로형태             NaN
#
# [153 rows x 2 columns]

# %%
accidList_new_Road = accidList_gu_road.groupby('도로형태')
accidList_new_Road

# %%
ax = accidList_new_Road.plot(kind='bar', figsize=(18, 5), rot=0, title="도로형태별(새 분류) 사고건수")
for p in ax.patches: 
    left, bottom, width, height = p.get_bbox().bounds 
    ax.annotate("%d"%(height), (left+width/2, height+2), ha='center')
plt.box(False)
plt.xlabel('')
plt.tight_layout()
plt.show()
